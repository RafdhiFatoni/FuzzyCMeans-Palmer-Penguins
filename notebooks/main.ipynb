# %%
# Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import os

# Add the parent directory to sys.path so 'src' can be imported
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
# Import Functions
from src.data_preprocessing import load_dataset
from src.data_preprocessing import remove_missing_values
from src.data_preprocessing import remove_noisy_gender
from src.data_preprocessing import plot_column_distributions
from src.data_preprocessing import plot_boxplots
from src.data_preprocessing import plot_correlation_heatmap
from src.data_preprocessing import plot_pie_chart

# %%
# Import Dataset
df = load_dataset('D:\Data Rafdhi\Programming\Programming Project (Git)\FuzzyCMeans-Palmer-Penguins\data\penguins_size.csv')
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# #### Pre-Processing

# %%
# Handle Missing Values
df = remove_missing_values(df)

# %%
# Remove noisy data
df = remove_noisy_gender(df)

# %% [markdown]
# #### Exploratory Data Analysis

# %%
# Plot column distributions
plot_column_distributions(df)

# %%
# Boxplot
plot_boxplots(df)

# %%
# Correlation Heatmap
plot_correlation_heatmap(df)

# %%
# Proportion of Species
plot_pie_chart(df, 'species')

# %%
# Proportion of Species
plot_pie_chart(df, 'island')

# %%
# Proportion of Species
plot_pie_chart(df, 'sex')

# %% [markdown]
# #### Build Model
